# %%
pip install google-play-scraper
# Out:
# Requirement already satisfied: google-play-scraper in /usr/local/lib/python3.11/dist-packages (1.2.7)

# %% [markdown]
# # IMPORT LIBRARY

# %%
from google_play_scraper import Sort, reviews
import pandas as p

# %%
# Ganti dengan ID aplikasi yang ingin kamu scrap, misalnya TikTok
app_id = 'com.ss.android.ugc.trill'

# Mengambil 100 ulasan terbaru
scrapreview, _ = reviews(
    app_id,
    lang='id',  # Bahasa Indonesia
    country='id',  # Negara Indonesia
    sort=Sort.NEWEST,  # Ulasan terbaru
    count=10000  # Jumlah ulasan yang ingin diambil
)

# %%
# Membuat DataFrame dari hasil scraping
app_reviews_df = pd.DataFrame(scrapreview)

# Menyimpan ke file CSV lengkap
app_reviews_df.to_csv("ulasan_tiktok.csv", index=False)

# %%
# Menampilkan lima baris pertama
app_reviews_df.head()
# Out:
#                                reviewId         userName  \
# 0  9f293c6a-953f-4476-9f2c-6d65d8a4f939  Pengguna Google
# 1  be33729a-97da-44a7-8607-cc5ff3c5a7f1  Pengguna Google
# 2  51d6608a-88a8-4ba6-acd8-9d836e842a4f  Pengguna Google
# 3  a1db1f60-4efc-4c38-a272-cb7f26da354d  Pengguna Google
# 4  fff6f5eb-1990-4537-b994-0326044e7a32  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  tolong pihak tiktok dari tadi saya donload men...      2              0
# 1                                        baik sekali      5              0
# 2  gw bingung sama tiktok, komentar yg bener di A...      1              0
# 3  baguss bangett ihh, adaa ajaa inspirasi baruu ...      5              0
# 4  Mohon di perbaiki lagi soal nya saya donlod su...      3              0
#
#   reviewCreatedVersion                  at replyContent repliedAt appVersion
# 0               39.4.3 2025-04-12 10:01:19         None       NaT     39.4.3
# 1                 None 2025-04-12 09:59:52         None       NaT       None
# 2                 None 2025-04-12 09:59:43         None       NaT       None
# 3               39.3.3 2025-04-12 09:57:35         None       NaT     39.3.3
# 4                 None 2025-04-12 09:56:14         None       NaT       None
